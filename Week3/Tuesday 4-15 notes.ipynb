# %% [markdown]
# Tuesday 4-15-2013 notes
# =

# %% [markdown]
# Create a very simple plot

# %%
import numpy as py
t = np.arange(0.0,1.0+0.01,0.01)
s=cos(2*2*pi*t)

# %%
plot(t,s)
xlabel("time(s)")
ylabel("mV")
title("yoloswag420blazeit",fontsize=100)
grid(True)
savefig("plot.png")

# %%
t = np.arange(0.0,1.0+0.01,0.01)
c=sin(2*2*pi*t)

# %%
plot(t,s, color="red", linewidth=8, label="label1")
plot(t,c, color = "green", linewidth=8, label="label2")
legend()
