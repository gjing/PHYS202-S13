# %% [markdown]
# Project 4
# =
# 3-D Pattern Recognition
# -
# George Jing

# %%
class Voxel:
    """A class to store the parameters of each voxel and calculate the gradient. Takes in a String parameter and parses it"""
    def __init__(self, data):
        self.volume = float(data.split(' ')[0])
        self.row = float(data.split(' ')[1])
        self.column = float(data.split(' ')[2])
        self.bucket = float(data.split(' ')[3])
        self.ADC = float(data.split(' ')[4])
    def setGradient(self, other):
        self.gradient = (other.ADC-self.ADC)

# %%
def getEvent(f, e_num):
    """Parses the file, looking for the string that begins with #### Event Number
        and then creates a voxel with each subsequent string, adding it to the array
        until it hits a line that contains "####" the array is returned"""
    line = f.readline()
    atline = False
    arr = []
    while not atline:
        if "#### Event " + str(e_num) in line:
            atline = True
        line = f.readline()
    atline = False
    while not atline:
        if line == '' or "#### Event " in line:
            return arr
        else:
            arr.append(Voxel(line))
        line = f.readline()

# %%
#plotting the data for event0
niffte = open("niffte_data.txt", 'r')
events = getEvent(niffte,99)
import math
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection='3d')
event1Row = []
event1Col = []
event1Buc = []
for voxel in events:
    event1Row.append(voxel.row)
    event1Col.append(voxel.column)
    event1Buc.append(voxel.bucket)
p = ax.scatter(event1Row,event1Col,event1Buc)
ax.set_xlabel('Event0 Row')
ax.set_ylabel('Event0 Column')
ax.set_zlabel('Event0 Bucket')
niffte.close()

# %%
def sortData(data, n):
    """takes the data and an event number sorts all the voxels by highest to lowest ADC"""
    return sorted(getEvent(data,n), key=lambda Voxel: Voxel.ADC)[::-1]

# %%
#testing for a random event
import random as rand
niffte = open("niffte_data.txt", 'r')
n = rand.randint(0,100)
events = sortData(niffte, n)
import math
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection='3d')
event1Row = []
event1Col = []
event1Buc = []
for voxel in events:
    event1Row.append(voxel.row)
    event1Col.append(voxel.column)
    event1Buc.append(voxel.bucket)
p = ax.scatter(event1Row,event1Col,event1Buc)
ax.set_xlabel('Event '+str(n)+' Row')
ax.set_ylabel('Event '+str(n)+' Column')
ax.set_zlabel('Event '+str(n)+' Bucket')
niffte.close()

# %%
def gradCutoff(data, cutoff):
    """creates a track and pool array determined by the cutoff and returns the arrays"""
    pool = []
    v = data[0]
    track = []
    track.append(v)
    for vox in data:
        vox.setGradient(v)
        #print vox.gradient
        if vox.gradient>cutoff:
            pool.append(vox)
        else:
            track.append(vox)
            v = vox
    return track, pool

# %%
import math
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
def graphSortedEvent(data,n,cutoff):
    """graphs the sorted data and shows the cufoff"""
    e = sortData(data,n)
    fig = figure()
    ax = fig.gca(projection='3d')
    eventTrackRow = []
    eventTrackCol = []
    eventTrackBuc = []
    eventPoolRow = []
    eventPoolCol = []
    eventPoolBuc = []
    sets = gradCutoff(e,cutoff)
    st = sorted(sets[0], key=lambda Voxel: Voxel.gradient)
    for voxel in st:
        eventTrackRow.append(voxel.row)
        eventTrackCol.append(voxel.column)
        eventTrackBuc.append(voxel.bucket)
    for voxel in sets[1]:
        eventPoolRow.append(voxel.row)
        eventPoolCol.append(voxel.column)
        eventPoolBuc.append(voxel.bucket)
    p = ax.scatter(eventTrackRow,eventTrackCol,eventTrackBuc, marker='^', s=10, color=numpy.random.rand(3,1))
    q = ax.scatter(eventPoolRow,eventPoolCol,eventPoolBuc, marker='v', s=10, color=numpy.random.rand(3,1))
    ax.set_xlabel('Event '+str(n)+' Row')
    ax.set_ylabel('Event '+str(n)+' Column')
    ax.set_zlabel('Event '+str(n)+' Bucket')
    legend()

# %%
#testing random events with random cutoffs
niffte = open("niffte_data.txt", 'r')
cutoff = rand.randint(1,20)
print "cutoff of "+str(cutoff)
graphSortedEvent(niffte,2,cutoff)
# Out:
# cutoff of 11
# C:\Users\user\AppData\Local\Enthought\Canopy\App\appdata\canopy-1.0.0.1160.win-x86_64\lib\site-packages\matplotlib\axes.py:4602: UserWarning: No labeled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labeled objects found. "

# %% [markdown]
# Completed project starts here
# =

# %%
import math
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

class Event:
    """A class to manipulate a list of Voxels"""
    def __init__(self, data):
        self.data = sorted(data, key=lambda Voxel: Voxel.ADC)[::-1]
        self.pool = []
        self.tracks = []
    def rawGraph(self):
        fig = figure()
        ax = fig.gca(projection='3d')
        eventRow = []
        eventCol = []
        eventBuc = []
        for voxel in self.data:
            eventRow.append(voxel.row)
            eventCol.append(voxel.column)
            eventBuc.append(voxel.bucket)
        p = ax.scatter(eventRow,eventCol,eventBuc)
        ax.set_xlabel('Event Row')
        ax.set_ylabel('Event Column')
        ax.set_zlabel('Event Bucket')
    def rawTracks(self, cutoff, i=0):
        """sets the tracks and orphans. It adds voxels to an array until it longer meets the gradient cutoff, then it adds that array to the tracks array
            then repeates with what is left until all the voxels are in an array in the tracks array."""
        dat = self.data
        if i<len(self.data):
            v = self.data[i]
            t = []
            for vox in dat:
                i+=1
                vox.setGradient(v)
                if vox.gradient<cutoff:
                    t.append(vox)
                else:
                    self.tracks.append(t)
                    self.rawTracks(cutoff,i)
        else:
            return None
    def setTracks(self,cutoff):
        """moves points from tracks from the tracks array of length less than 3 to the poolo"""
        self.rawTracks(cutoff)
        for track in self.tracks:
            if len(track)<3:
                for t in track:
                    self.pool.append(t)
                self.tracks.remove(track)
        self.pool = sorted(self.pool, key=lambda Voxel: Voxel.ADC)[::-1]
    def graphEvent(self, cutoff, orphans):
        self.setTracks(cutoff)
        """graphs the tracks and orphans"""
        fig = figure()
        ax = fig.gca(projection='3d')
        for t in self.tracks:
            eventR = []
            eventC = []
            eventB = []
            for vox in t:
                eventR.append(vox.row)
                eventC.append(vox.column)
                eventB.append(vox.bucket)
                p = ax.scatter(eventR,eventC,eventB, marker='^', s=10, color=numpy.random.rand(3,1))
        eventPoolRow = []
        eventPoolCol = []
        eventPoolBuc = []
        if orphans == True:
            for voxel in self.pool:
                eventPoolRow.append(voxel.row)
                eventPoolCol.append(voxel.column)
                eventPoolBuc.append(voxel.bucket)
            q = ax.scatter(eventPoolRow,eventPoolCol,eventPoolBuc, marker='v', s=10, color=numpy.random.rand(3,1))
        ax.set_xlabel('Event Row')
        ax.set_ylabel('Event Column')
        ax.set_zlabel('Event Bucket')

# %%
#making a list of events

niffte = open("niffte_data.txt", 'r')
line = niffte.readline()
line = niffte.readline()
events = []
for i in range(0,100):
    arr = []
    boolean = True
    while boolean:
        if line == '' or "#### Event " in line:
            events.append(Event(arr))
            boolean = False
        else:
            arr.append(Voxel(line))
        line = niffte.readline()
niffte.close()

# %%
events[2].rawTracks(5, events[2].data)

# %%
len(events[2].tracks)
events[2].graphEvent[5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-f3ebe02df6e4> in <module>()
#       1 len(events[2].tracks)
# ----> 2 events[2].graphEvent[5]
#
# TypeError: 'instancemethod' object has no attribute '__getitem__'

# %%
#not working now because my track finder isn't working properly but it should work if it was
orphans = []
tracks = []
x = list(xrange(100))
for event in events:
    event.graphEvent(5,True)
    orphans.append(len(event.pool))
    tracks.append(len(event.tracks))
subplot(2,1,2)
bar(x,orphans)
title('Orphans')
xlabel('Event')
ylabel('Orphans')
subplot(2,1,1)
bar(x,tracks, color='red')
title('Tracks')
xlabel('Event')
ylabel('Tracks')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-77854c42d1f8> in <module>()
#       4 x = list(xrange(100))
#       5 for event in events:
# ----> 6     event.graphEvent(5,True)
#       7     orphans.append(len(event.pool))
#       8     tracks.append(len(event.tracks))
#
# <ipython-input-9-df892610afce> in graphEvent(self, cutoff, orphans)
#      62                 eventC.append(vox.column)
#      63                 eventB.append(vox.bucket)
# ---> 64                 p = ax.scatter(eventR,eventC,eventB, marker='^', s=10, color=numpy.random.rand(3,1))
#      65         eventPoolRow = []
#      66         eventPoolCol = []
#
# C:\Users\user\AppData\Local\Enthought\Canopy\App\appdata\canopy-1.0.0.1160.win-x86_64\lib\site-packages\mpl_toolkits\mplot3d\axes3d.pyc in scatter(self, xs, ys, zs, zdir, s, c, *args, **kwargs)
#    1955         xs, ys, zs, s, c = cbook.delete_masked_points(xs, ys, zs, s, c)
#    1956
# -> 1957         patches = Axes.scatter(self, xs, ys, s=s, c=c, *args, **kwargs)
#    1958         if not cbook.iterable(zs):
#    1959             is_2d = True
#
# C:\Users\user\AppData\Local\Enthought\Canopy\App\appdata\canopy-1.0.0.1160.win-x86_64\lib\site-packages\matplotlib\axes.pyc in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, faceted, verts, **kwargs)
#    6138             self.set_ymargin(0.05)
#    6139
# -> 6140         self.add_collection(collection)
#    6141         self.autoscale_view()
#    6142
#
# C:\Users\user\AppData\Local\Enthought\Canopy\App\appdata\canopy-1.0.0.1160.win-x86_64\lib\site-packages\matplotlib\axes.pyc in add_collection(self, collection, autolim)
#    1489         if autolim:
#    1490             if collection._paths and len(collection._paths):
# -> 1491                 self.update_datalim(collection.get_datalim(self.transData))
#    1492
#    1493         collection._remove_method = lambda h: self.collections.remove(h)
#
# C:\Users\user\AppData\Local\Enthought\Canopy\App\appdata\canopy-1.0.0.1160.win-x86_64\lib\site-packages\matplotlib\collections.pyc in get_datalim(self, transData)
#     186         result = mpath.get_path_collection_extents(
#     187             transform.frozen(), paths, self.get_transforms(),
# --> 188             offsets, transOffset.frozen())
#     189         result = result.inverse_transformed(transData)
#     190         return result
#
# C:\Users\user\AppData\Local\Enthought\Canopy\App\appdata\canopy-1.0.0.1160.win-x86_64\lib\site-packages\matplotlib\transforms.pyc in frozen(self)
#    2122         frozen = composite_transform_factory(self._a.frozen(), self._b.frozen())
#    2123         if not isinstance(frozen, CompositeGenericTransform):
# -> 2124             return frozen.frozen()
#    2125         return frozen
#    2126     frozen.__doc__ = Transform.frozen.__doc__
#
# C:\Users\user\AppData\Local\Enthought\Canopy\App\appdata\canopy-1.0.0.1160.win-x86_64\lib\site-packages\matplotlib\transforms.pyc in frozen(self)
#    1582
#    1583     def frozen(self):
# -> 1584         return Affine2D(self.get_matrix().copy())
#    1585     frozen.__doc__ = AffineBase.frozen.__doc__
#    1586
#
# C:\Users\user\AppData\Local\Enthought\Canopy\App\appdata\canopy-1.0.0.1160.win-x86_64\lib\site-packages\matplotlib\transforms.pyc in get_matrix(self)
#    2265             self._mtx = np.dot(
#    2266                 self._b.get_matrix(),
# -> 2267                 self._a.get_matrix())
#    2268             self._inverted = None
#    2269             self._invalid = 0
#
# KeyboardInterrupt:
