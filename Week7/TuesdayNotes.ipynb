# %%
g = 9.8
l = 0.5
th0 = 20.*pi/180

t = arange(0.,10.+0.01,0.01)
theta_app = lambda t: th0*cos(sqrt(g/l)*t)
    
plot(t,theta_app(t))
show()

# %%
def deriv(theta_current,t):
    g = 9.8
    l = 0.5
    theta = theta_current[0]
    omega = theta_current[1]
    dtheta = omega
    domega = -(g/l)*sin(theta)
    return array([dtheta,domega])

# %%
from scipy.integrate import odeint

omega0 = 0
theta_init = array([th0,omega0])

theta = odeint(deriv,theta_init,t)

theta.shape
# Out:
# (1001, 2)

# %%
plot(t,theta_app(t), 'b-', t, theta[:,0], 'r--')
show()

# %%
th0 = 50.*pi/180

theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)

plot(t,theta_app(t),'b-',t,theta[:,0],'r--')
show()

# %% [markdown]
# Exercises
# =
# 1)
# -

# %%
th0 = 0

theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)

plot(t,theta_app(t),'b-',t,theta[:,0],'r--')
show()

# %%
th0 = pi/4

theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)

plot(t,theta_app(t),'b-',t,theta[:,0],'r--')
show()

# %%
th0 = pi/2

theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)

plot(t,theta_app(t),'b-',t,theta[:,0],'r--')
show()

# %%
th0 = 3*pi/4

theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)

plot(t,theta_app(t),'b-',t,theta[:,0],'r--')
show()

# %%
th0 = pi

theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)

plot(t,theta_app(t),'b-',t,theta[:,0],'r--')
show()

# %% [markdown]
# 2
# -

# %%
th0 = .95*pi

theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)

plot(t,theta[:,0],'p-')
show()

# %%
th0 = .95*pi

theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)

plot(t,theta[:,1],'p-')
show()

# %%
th0 = .95*pi

theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)

plot(theta[:,0],theta[:,1],'p-')
show()

# %% [markdown]
# 3
# -

# %%
th0 = .95*pi

t = arange(0.,50.+0.01,0.01)
theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)
em = g*l*(sin(theta[:,0])) + 0.5*l*(theta[:,1])**2
plot(t,em,'r-')
show()

# %% [markdown]
# 4
# -

# %%
th0 = pi

t = arange(0.,50.+0.01,0.01)
theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)
em = g*l*(sin(theta[:,0])) + 0.5*l*(theta[:,1])**2
plot(t,em,'r-', label="E/m vs t")
plot(t,theta[:,0], "b-", label="$\theta vs t$")
plot(t,theta[:,1], "y-", label="$\omega vs t$")
legend(loc=3)
show()

# %%
th0 = pi-.0000001

theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)
em = g*l*(sin(theta[:,0]))**2 + 0.5*l*(theta[:,1])**2
plot(t,em,'r-', label="E/m vs t")
plot(t,theta[:,0], "b-", label="$\theta vs t$")
plot(t,theta[:,1], "y-", label="$\omega vs t$")
legend(loc=3)
show()
