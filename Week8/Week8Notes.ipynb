# %% [markdown]
# Random Numbers and Monte Carlo Simulations
# =

# %%
import numpy.random
numpy.random?

# %%
print numpy.random.random(5)
print numpy.random.random(5)
# Out:
# [ 0.83620599  0.23083533  0.5862991   0.46078672  0.09085942]
# [ 0.9903361   0.16770193  0.74693142  0.16692777  0.08871026]

# %%
numpy.random.seed(4242)
print numpy.random.random(5)
# Out:
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
numpy.random.seed(None)
print numpy.random.random(5)
# Out:
# [ 0.69589896  0.26571687  0.00325156  0.13295965  0.00900673]

# %%
numpy.random.seed(4242)
print numpy.random.random(5)
numpy.random.seed(None)
# Out:
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
x = arange(0., pi+0.001, 0.01)
f = lambda x: sin(x)/2.
F = lambda x: (cos(0)-cos(x))/2.

plot(x,f(x),label='True distribution',lw=3)
plot(x,F(x),label='Cumulative fuction',lw=3)

xlim(0,3.5)
ylim(0,1.1)

legend(loc=0)
show()

# %%
#number of samples
N = 10000

#N random numbers between 0 and 1
z = numpy.random.random_sample(N)

#inverse CDF
Finv = lambda z: arccos(cos(0)-2*z)
    
#sampled x values
xsamples = Finv(z)

#how do they compare to the original?
hist(xsamples,50,normed=True,label="Sampled distribution")
plot(x,f(x),label="True distribution",lw=3, color='red')

xlim(0,pi)
ylim(0,0.7)

legend(loc=0)
show()

# %% [markdown]
# Exercise 1. Exponential function - analytic
# -
# $f(x)=\lambda e^{-\lambda x}$

# %% [markdown]
# (a) Find the CDF F(x) and invert it analytically

# %% [markdown]
# $F(x) = 1-e^{-\lambda x}$
#
# $F^{-1}(z) = -ln(1-z)/\lambda$

# %% [markdown]
# (b) Plot teh function and teh CDF

# %%
l = 1
x = arange(0,5,.01)
f = lambda x: l*e**-(l*x)
F = lambda x: 1-e**-(l*x)

plot(x,f(x),label='True distribution',lw=3)
plot(x,F(x),label='Cumulative function',lw=3)

legend(loc=0)
show()

# %%
import math
#number of samples
N = 10000

#N random numbers between 0 and 1
z = numpy.random.random_sample(N)

#inverse CDF
Finv = lambda z: -numpy.log(1-z)/l
    
#sampled x values
xsamples = Finv(z)

#how do they compare to the original?
hist(xsamples,50,normed=True,label="Sampled distribution")
plot(x,f(x),label="True distribution",lw=3, color='red')

legend(loc=0)
show()

# %% [markdown]
# Exercise 2. Exponential function - numerical
# -
